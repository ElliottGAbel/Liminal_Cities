# %%
import pandas as pd
import geopandas
import matplotlib.pyplot as plt
import numpy as np
import glob

# %matplotlib inline
# %config InlineBackend.figure_format ='retina'

# %%
from config import *

# %%
gdf2019 = pd.read_pickle(sharedFolder + 'gdf2019.pkl')
gdf2020 = pd.read_pickle(sharedFolder + 'gdf2020.pkl')

# %%
gdf = pd.merge(
    gdf2019,
    gdf2020[['CBSA', 'commuteBuffCount', 'workingPop', 'commutePercent', 'liminal']],
    on='CBSA',
    suffixes=('_19', '_20')
)

#It is liminal, if it was liminal in 2019 or 2020
gdf['liminal'] = gdf['liminal_19'] | gdf['liminal_20']
gdf = gdf.drop(columns=['liminal_19', 'liminal_20'])
gdf[gdf['liminal']]
# Out:
#       CBSA                           LSAD  POPESTIMATE2020  POPESTIMATE2021  \
# 40   14100  Metropolitan Statistical Area            82811            83083
# 55   16020  Metropolitan Statistical Area            97543            97757
# 80   18020  Metropolitan Statistical Area            82216            82730
# 83   18700  Metropolitan Statistical Area            95208            96277
# 85   19060  Metropolitan Statistical Area            94845            94557
# ..     ...                            ...              ...              ...
# 914  48940  Micropolitan Statistical Area            42023            42100
# 915  48980  Micropolitan Statistical Area            78807            78283
# 918  49100  Micropolitan Statistical Area            49640            49750
# 920  49260  Micropolitan Statistical Area            24145            23947
# 924  49780  Micropolitan Statistical Area            86450            86574
#
#      POPESTIMATE2022                    NAME  \
# ...

# %%
gdf.to_pickle(sharedFolder + 'gdf.pkl')
