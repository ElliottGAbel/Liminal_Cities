# %%
import pandas as pd
import geopandas as gpd
from config import *

# %%
csvs = {
    2010: pd.read_csv('combined2010.csv'),
    2015: pd.read_csv('combined2015.csv'),
    2019: pd.read_csv('combined2019.csv'),
    2020: pd.read_csv('combined2020.csv'),
    2021: pd.read_csv('combined2021.csv')
}
codebook = pd.read_excel('Codebook.xlsx')

# %%
mig = gpd.GeoDataFrame(pd.read_pickle(dataFolder + '2010-2022_net_migration.pkl'))

mig = mig.reset_index().rename(columns={
    'cbsa': 'CBSA',
    'NPOPCHG_2010': 'NPOPCHG2010',
    'NPOPCHG_2011': 'NPOPCHG2011',
    'NPOPCHG_2012': 'NPOPCHG2012',
    'NPOPCHG_2013': 'NPOPCHG2013',
    'NPOPCHG_2014': 'NPOPCHG2014',
    'NPOPCHG_2015': 'NPOPCHG2015',
    'NPOPCHG_2016': 'NPOPCHG2016',
    'NPOPCHG_2017': 'NPOPCHG2017',
    'NPOPCHG_2018': 'NPOPCHG2018',
    'NPOPCHG_2019': 'NPOPCHG2019',
    'NPOPCHG_2020': 'NPOPCHG2020',
    'NATURALCHG2021': 'NATURALINC2021',
    'RNATURALCHG2021': 'RNATURALINC2021',
    'NATURALCHG2022': 'NATURALINC2022',
    'RNATURALCHG2022': 'RNATURALINC2022'
}).drop(columns=[
    'STNAME', 'CTYNAME', 'CENSUS2010POP' #CENSUS2010POP is a string??
])

# %%
data = pd.DataFrame(index=pd.Index([], name='CBSA'))

for year, csv in csvs.items():
    csv.set_index('CBSA', inplace=True)
    csv.rename(columns={
        name: (name, year) for name in csv.columns
    }, inplace=True)

    data = pd.merge(data, csv, on='CBSA', how='outer')

# %%
migCols = [
    'POPESTIMATE',
    'NPOPCHG',
    'BIRTHS',
    'DEATHS',
    'NATURALINC',
    'INTERNATIONALMIG',
    'DOMESTICMIG',
    'NETMIG',
    'RESIDUAL',
    'GQESTIMATES'
]

migRCols = [
    'RBIRTH',
    'RDEATH',
    'RNATURALINC',
    'RINTERNATIONALMIG',
    'RDOMESTICMIG',
    'RNETMIG'
]

newNames = {}

for col in migCols:
    for year in range(2010, 2022+1):
        newNames[col + str(year)] = (col, year)

for col in migRCols:
    for year in range(2011, 2022+1):
        newNames[col + str(year)] = (col, year)

mig = mig.set_index('CBSA')[newNames.keys()].rename(columns=newNames)

# %%
data = data.drop(columns=[c for c in mig.columns if c in data.columns])
data = data.drop(columns=[('NPOPCHG_', 2010), ('NPOPCHG_', 2015), ('NPOPCHG_', 2019)])
data = pd.merge(data, mig, on='CBSA', how='outer')

# %%
cols = []

for i, row in codebook.iterrows():
    name = row['column name']
    years = str(row['year(s)'])
    
    if name in {'CBSA', 'geometry'}: continue
    
    for year in years.split(','):
        year = int(year)
        cols.append((name, year))

for col in sorted(data.columns):
    if not col in cols:
        print(col, "was removed")

data = data[cols]
# Out:
# ('LSAD', 2010) was removed
# ('LSAD', 2015) was removed
# ('LSAD', 2019) was removed
# ('LSAD', 2021) was removed
# ('NAME', 2010) was removed
# ('NAME', 2015) was removed
# ('NAME', 2020) was removed
# ('NAME', 2021) was removed
# ('Num_Comp_Info_Res', 2010) was removed
# ('Num_Comp_Info_Res', 2015) was removed
# ('Num_Comp_Info_Res', 2019) was removed
# ('Num_Comp_Info_Res', 2021) was removed
# ('Num_Comp_Programmer', 2010) was removed
# ('Num_Comp_Programmer', 2015) was removed
# ('Num_Comp_Programmer', 2019) was removed
# ('Num_Comp_Programmer', 2021) was removed
# ('Num_Comp_Sys_Analyst', 2010) was removed
# ('Num_Comp_Sys_Analyst', 2015) was removed
# ('Num_Comp_Sys_Analyst', 2019) was removed
# ('Num_Comp_Sys_Analyst', 2021) was removed
# ('Num_Info_Sec_Analyst', 2010) was removed
# ('Num_Info_Sec_Analyst', 2015) was removed
# ('Num_Info_Sec_Analyst', 2019) was removed
# ('Num_Info_Sec_Analyst', 2021) was removed
# ('Num_Soft_Dev', 2010) was removed
# ('Num_Soft_Dev', 2015) was removed
# ('Num_Soft_Dev', 2019) was removed
# ('Num_Soft_Dev', 2021) was removed
# ('Num_Soft_Qual', 2010) was removed
# ('Num_Soft_Qual', 2015) was removed
# ('Num_Soft_Qual', 2019) was removed
# ('Num_Soft_Qual', 2021) was removed
# ('Num_Total_Worker', 2010) was removed
# ('Num_Total_Worker', 2015) was removed
# ('Num_Total_Worker', 2019) was removed
# ('Num_Total_Worker', 2021) was removed
# ('Num_Web_Dev', 2010) was removed
# ('Num_Web_Dev', 2015) was removed
# ('Num_Web_Dev', 2019) was removed
# ('Num_Web_Dev', 2021) was removed
# ('RBIRTHSw', 2010) was removed
# ('RBIRTHSw', 2015) was removed
# ('RBIRTHSw', 2019) was removed
# ('RBIRTHSw', 2021) was removed
# ('RDEATHSw', 2010) was removed
# ('RDEATHSw', 2015) was removed
# ('RDEATHSw', 2019) was removed
# ('RDEATHSw', 2021) was removed
# ('RDOMESTICMIGw', 2010) was removed
# ('RDOMESTICMIGw', 2015) was removed
# ('RDOMESTICMIGw', 2019) was removed
# ('RDOMESTICMIGw', 2021) was removed
# ('RINTERNATIONALMIGw', 2010) was removed
# ('RINTERNATIONALMIGw', 2015) was removed
# ('RINTERNATIONALMIGw', 2019) was removed
# ('RINTERNATIONALMIGw', 2021) was removed
# ('RNATURALINCw', 2010) was removed
# ('RNATURALINCw', 2015) was removed
# ('RNATURALINCw', 2019) was removed
# ('RNATURALINCw', 2021) was removed
# ('RNETMIGw', 2010) was removed
# ('RNETMIGw', 2015) was removed
# ('RNETMIGw', 2019) was removed
# ('RNETMIGw', 2021) was removed
# ('inBuff', 2010) was removed
# ('inBuff', 2015) was removed
# ('inBuff', 2020) was removed
# ('inBuff', 2021) was removed
# ('liminal', 2010) was removed
# ('liminal', 2015) was removed
# ('liminal', 2019) was removed
# ('liminal', 2021) was removed
# ('metro', 2010) was removed
# ('metro', 2015) was removed
# ('metro', 2019) was removed
# ('metro', 2020) was removed
# ('micro', 2010) was removed
# ('micro', 2015) was removed
# ('micro', 2019) was removed
# ('micro', 2020) was removed

# %%
data.columns = pd.MultiIndex.from_tuples(data.columns, names=('Variable', 'Year')) #Create MultiIndex
data
# Out:
# Variable                                  NAME                           LSAD  \
# Year                                      2019                           2020
# CBSA
# 12020                 Athens-Clarke County, GA  Metropolitan Statistical Area
# 12060     Atlanta-Sandy Springs-Alpharetta, GA  Metropolitan Statistical Area
# 12100              Atlantic City-Hammonton, NJ  Metropolitan Statistical Area
# 12120                               Atmore, AL  Micropolitan Statistical Area
# 12140                               Auburn, IN  Micropolitan Statistical Area
# ...                                        ...                            ...
# 49080                           Winnemucca, NV  Micropolitan Statistical Area
# 49100                               Winona, MN  Micropolitan Statistical Area
# 49180                        Winston-Salem, NC  Metropolitan Statistical Area
# 49220          Wisconsin Rapids-Marshfield, WI  Micropolitan Statistical Area
# 14160                                      NaN                            NaN
#
# Variable  metro  micro inBuff commuteBuffCount            workingPop  \
# Year       2021   2021   2019             2019       2020       2019
# CBSA
# 12020     False  False   True          21008.0    20168.0    80835.0
# 12060      True  False   True        2412279.0  2346403.0  2590292.0
# 12100     False  False   True          27041.0    24765.0   123380.0
# 12120     False   True  False              0.0        0.0    12416.0
# 12140     False   True   True            728.0      624.0    20907.0
# ...         ...    ...    ...              ...        ...        ...
# 49080     False   True  False              0.0        0.0     7520.0
# 49100     False   True   True           1488.0     1382.0    22024.0
# 49180     False  False   True          41421.0    40087.0   290914.0
# 49220     False   True  False              0.0        0.0    37117.0
# 14160       NaN    NaN    NaN              NaN        NaN        NaN
#
# Variable            commutePercent  ... Tot_Bldgs          Tot_Bldgs_Value  \
# Year           2020           2019  ...      2019     2021            2010
# CBSA                                ...
# 12020       78919.0      25.988743  ...     947.0    928.0    4.513729e+07
# 12060     2517685.0      93.127686  ...   26484.0  31960.0    1.284808e+09
# 12100      106316.0      21.916842  ...     421.0    575.0    7.940623e+07
# 12120       11212.0       0.000000  ...       7.0     10.0    4.594400e+05
# 12140       20137.0       3.482087  ...     150.0    138.0    1.119984e+07
# ...             ...            ...  ...       ...      ...             ...
# 49080        7393.0       0.000000  ...      14.0     31.0    1.831417e+06
# 49100       20277.0       6.756266  ...      57.0     62.0    1.520123e+07
# 49180      280860.0      14.238228  ...    3176.0   3911.0    1.914697e+08
# 49220       35449.0       0.000000  ...     114.0    117.0    1.372929e+07
# 14160           NaN            NaN  ...       NaN      NaN             NaN
#
# Variable                                           Tot_Units           \
# Year              2015          2019          2021      2010     2015
# CBSA
# 12020     1.834011e+08  2.605810e+08  3.753031e+08     226.0   1159.0
# 12060     5.318834e+09  6.783502e+09  8.721861e+09    7608.0  30342.0
# 12100     1.122180e+08  1.477606e+08  1.940337e+08     512.0    710.0
# 12120     1.740280e+05  9.137180e+05  1.445752e+06       7.0      2.0
# 12140     1.933319e+07  4.038081e+07  4.435193e+07      70.0     98.0
# ...                ...           ...           ...       ...      ...
# 49080     6.324198e+06  2.396881e+06  5.397395e+06      18.0     51.0
# 49100     1.223176e+07  1.457054e+07  1.991332e+07     113.0     97.0
# 49180     3.228380e+08  6.694921e+08  1.085525e+09    1467.0   2044.0
# 49220     2.890507e+07  3.929103e+07  4.078070e+07     109.0    271.0
# 14160              NaN           NaN           NaN       NaN      NaN
#
# Variable
# Year         2019     2021
# CBSA
# 12020      1591.0   1848.0
# 12060     32836.0  39466.0
# 12100       957.0    804.0
# 12120         7.0     10.0
# 12140       150.0    138.0
# ...           ...      ...
# 49080        17.0     31.0
# 49100        95.0    103.0
# 49180      3334.0   4206.0
# 49220       274.0    120.0
# 14160         NaN      NaN
#
# [927 rows x 605 columns]

# %%
data.to_csv('dataset.csv')
data.to_excel('dataset.xlsx')

# %%
df = pd.DataFrame()

print('CBSA', len(data.index))

for name in data.columns:
    name = tuple(name)
    col = data[name]
    print(name, (~col.isna()).sum())
    # df.loc['missing', name] = float(col.isna().sum())
    # df.loc['missing %', name] = col.isna().mean() * 100
    # df.loc['zeros', name] = (col == 0).sum()
    # df.loc['zeros %', name] = (col == 0).mean() * 100

# df = df.T
# df
# Out:
# CBSA 927
# ('NAME', 2019) 926
# ('LSAD', 2020) 926
# ('metro', 2021) 926
# ('micro', 2021) 926
# ('inBuff', 2019) 926
# ('commuteBuffCount', 2019) 926
# ('commuteBuffCount', 2020) 926
# ('workingPop', 2019) 926
# ('workingPop', 2020) 926
# ('commutePercent', 2019) 926
# ('commutePercent', 2020) 926
# ('liminal', 2020) 926
# ('Days with AQI', 2010) 519
# ('Days with AQI', 2015) 512
# ('Days with AQI', 2019) 502
# ('Days with AQI', 2021) 493
# ('Good Days', 2010) 519
# ('Good Days', 2015) 512
# ('Good Days', 2019) 502
# ('Good Days', 2021) 493
# ('Moderate Days', 2010) 519
# ('Moderate Days', 2015) 512
# ('Moderate Days', 2019) 502
# ('Moderate Days', 2021) 493
# ('Unhealthy for Sensitive Groups Days', 2010) 519
# ('Unhealthy for Sensitive Groups Days', 2015) 512
# ('Unhealthy for Sensitive Groups Days', 2019) 502
# ('Unhealthy for Sensitive Groups Days', 2021) 493
# ('Unhealthy Days', 2010) 519
# ('Unhealthy Days', 2015) 512
# ('Unhealthy Days', 2019) 502
# ('Unhealthy Days', 2021) 493
# ('Very Unhealthy Days', 2010) 519
# ('Very Unhealthy Days', 2015) 512
# ('Very Unhealthy Days', 2019) 502
# ('Very Unhealthy Days', 2021) 493
# ('Hazardous Days', 2010) 519
# ('Hazardous Days', 2015) 512
# ('Hazardous Days', 2019) 502
# ('Hazardous Days', 2021) 493
# ('Max AQI', 2010) 519
# ('Max AQI', 2015) 512
# ('Max AQI', 2019) 502
# ('Max AQI', 2021) 493
# ('90th Percentile AQI', 2010) 519
# ('90th Percentile AQI', 2015) 512
# ('90th Percentile AQI', 2019) 502
# ('90th Percentile AQI', 2021) 493
# ('Median AQI', 2010) 519
# ('Median AQI', 2015) 512
# ('Median AQI', 2019) 502
# ('Median AQI', 2021) 493
# ('Days CO', 2010) 519
# ('Days CO', 2015) 512
# ('Days CO', 2019) 502
# ('Days CO', 2021) 493
# ('Days NO2', 2010) 519
# ('Days NO2', 2015) 512
# ('Days NO2', 2019) 502
# ('Days NO2', 2021) 493
# ('Days Ozone', 2010) 519
# ('Days Ozone', 2015) 512
# ('Days Ozone', 2019) 502
# ('Days Ozone', 2021) 493
# ('Days PM2.5', 2010) 519
# ('Days PM2.5', 2015) 512
# ('Days PM2.5', 2019) 502
# ('Days PM2.5', 2021) 493
# ('Days PM10', 2010) 519
# ('Days PM10', 2015) 512
# ('Days PM10', 2019) 502
# ('Days PM10', 2021) 493
# ('POPESTIMATE', 2010) 922
# ('POPESTIMATE', 2011) 922
# ('POPESTIMATE', 2012) 922
# ('POPESTIMATE', 2013) 922
# ('POPESTIMATE', 2014) 922
# ('POPESTIMATE', 2015) 922
# ('POPESTIMATE', 2016) 922
# ('POPESTIMATE', 2017) 922
# ('POPESTIMATE', 2018) 922
# ('POPESTIMATE', 2019) 922
# ('POPESTIMATE', 2020) 922
# ('POPESTIMATE', 2021) 922
# ('POPESTIMATE', 2022) 922
# ('NPOPCHG', 2010) 922
# ('NPOPCHG', 2011) 922
# ('NPOPCHG', 2012) 922
# ('NPOPCHG', 2013) 922
# ('NPOPCHG', 2014) 922
# ('NPOPCHG', 2015) 922
# ('NPOPCHG', 2016) 922
# ('NPOPCHG', 2017) 922
# ('NPOPCHG', 2018) 922
# ('NPOPCHG', 2019) 922
# ('NPOPCHG', 2020) 922
# ('NPOPCHG', 2021) 922
# ('NPOPCHG', 2022) 922
# ('BIRTHS', 2010) 922
# ('BIRTHS', 2011) 922
# ('BIRTHS', 2012) 922
# ('BIRTHS', 2013) 922
# ('BIRTHS', 2014) 922
# ('BIRTHS', 2015) 922
# ('BIRTHS', 2016) 922
# ('BIRTHS', 2017) 922
# ('BIRTHS', 2018) 922
# ('BIRTHS', 2019) 922
# ('BIRTHS', 2020) 922
# ('BIRTHS', 2021) 922
# ('BIRTHS', 2022) 922
# ('DEATHS', 2010) 922
# ('DEATHS', 2011) 922
# ('DEATHS', 2012) 922
# ('DEATHS', 2013) 922
# ('DEATHS', 2014) 922
# ('DEATHS', 2015) 922
# ('DEATHS', 2016) 922
# ('DEATHS', 2017) 922
# ('DEATHS', 2018) 922
# ('DEATHS', 2019) 922
# ('DEATHS', 2020) 922
# ('DEATHS', 2021) 922
# ('DEATHS', 2022) 922
# ('NATURALINC', 2010) 922
# ('NATURALINC', 2011) 922
# ('NATURALINC', 2012) 922
# ('NATURALINC', 2013) 922
# ('NATURALINC', 2014) 922
# ('NATURALINC', 2015) 922
# ('NATURALINC', 2016) 922
# ('NATURALINC', 2017) 922
# ('NATURALINC', 2018) 922
# ('NATURALINC', 2019) 922
# ('NATURALINC', 2020) 922
# ('NATURALINC', 2021) 922
# ('NATURALINC', 2022) 922
# ('INTERNATIONALMIG', 2010) 922
# ('INTERNATIONALMIG', 2011) 922
# ('INTERNATIONALMIG', 2012) 922
# ('INTERNATIONALMIG', 2013) 922
# ('INTERNATIONALMIG', 2014) 922
# ('INTERNATIONALMIG', 2015) 922
# ('INTERNATIONALMIG', 2016) 922
# ('INTERNATIONALMIG', 2017) 922
# ('INTERNATIONALMIG', 2018) 922
# ('INTERNATIONALMIG', 2019) 922
# ('INTERNATIONALMIG', 2020) 922
# ('INTERNATIONALMIG', 2021) 922
# ('INTERNATIONALMIG', 2022) 922
# ('DOMESTICMIG', 2010) 922
# ('DOMESTICMIG', 2011) 922
# ('DOMESTICMIG', 2012) 922
# ('DOMESTICMIG', 2013) 922
# ('DOMESTICMIG', 2014) 922
# ('DOMESTICMIG', 2015) 922
# ('DOMESTICMIG', 2016) 922
# ('DOMESTICMIG', 2017) 922
# ('DOMESTICMIG', 2018) 922
# ('DOMESTICMIG', 2019) 922
# ('DOMESTICMIG', 2020) 922
# ('DOMESTICMIG', 2021) 922
# ('DOMESTICMIG', 2022) 922
# ('NETMIG', 2010) 922
# ('NETMIG', 2011) 922
# ('NETMIG', 2012) 922
# ('NETMIG', 2013) 922
# ('NETMIG', 2014) 922
# ('NETMIG', 2015) 922
# ('NETMIG', 2016) 922
# ('NETMIG', 2017) 922
# ('NETMIG', 2018) 922
# ('NETMIG', 2019) 922
# ('NETMIG', 2020) 922
# ('NETMIG', 2021) 922
# ('NETMIG', 2022) 922
# ('RESIDUAL', 2010) 922
# ('RESIDUAL', 2011) 922
# ('RESIDUAL', 2012) 922
# ('RESIDUAL', 2013) 922
# ('RESIDUAL', 2014) 922
# ('RESIDUAL', 2015) 922
# ('RESIDUAL', 2016) 922
# ('RESIDUAL', 2017) 922
# ('RESIDUAL', 2018) 922
# ('RESIDUAL', 2019) 922
# ('RESIDUAL', 2020) 922
# ('RESIDUAL', 2021) 922
# ('RESIDUAL', 2022) 922
# ('GQESTIMATES', 2010) 922
# ('GQESTIMATES', 2011) 922
# ('GQESTIMATES', 2012) 922
# ('GQESTIMATES', 2013) 922
# ('GQESTIMATES', 2014) 922
# ('GQESTIMATES', 2015) 922
# ('GQESTIMATES', 2016) 922
# ('GQESTIMATES', 2017) 922
# ('GQESTIMATES', 2018) 922
# ('GQESTIMATES', 2019) 922
# ('GQESTIMATES', 2020) 922
# ('GQESTIMATES', 2021) 922
# ('GQESTIMATES', 2022) 922
# ('RBIRTH', 2011) 922
# ('RBIRTH', 2012) 922
# ('RBIRTH', 2013) 922
# ('RBIRTH', 2014) 922
# ('RBIRTH', 2015) 922
# ('RBIRTH', 2016) 922
# ('RBIRTH', 2017) 922
# ('RBIRTH', 2018) 922
# ('RBIRTH', 2019) 922
# ('RBIRTH', 2020) 922
# ('RBIRTH', 2021) 922
# ('RBIRTH', 2022) 922
# ('RDEATH', 2011) 922
# ('RDEATH', 2012) 922
# ('RDEATH', 2013) 922
# ('RDEATH', 2014) 922
# ('RDEATH', 2015) 922
# ('RDEATH', 2016) 922
# ('RDEATH', 2017) 922
# ('RDEATH', 2018) 922
# ('RDEATH', 2019) 922
# ('RDEATH', 2020) 922
# ('RDEATH', 2021) 922
# ('RDEATH', 2022) 922
# ('RNATURALINC', 2011) 922
# ('RNATURALINC', 2012) 922
# ('RNATURALINC', 2013) 922
# ('RNATURALINC', 2014) 922
# ('RNATURALINC', 2015) 922
# ('RNATURALINC', 2016) 922
# ('RNATURALINC', 2017) 922
# ('RNATURALINC', 2018) 922
# ('RNATURALINC', 2019) 922
# ('RNATURALINC', 2020) 922
# ('RNATURALINC', 2021) 922
# ('RNATURALINC', 2022) 922
# ('RINTERNATIONALMIG', 2011) 922
# ('RINTERNATIONALMIG', 2012) 922
# ('RINTERNATIONALMIG', 2013) 922
# ('RINTERNATIONALMIG', 2014) 922
# ('RINTERNATIONALMIG', 2015) 922
# ('RINTERNATIONALMIG', 2016) 922
# ('RINTERNATIONALMIG', 2017) 922
# ('RINTERNATIONALMIG', 2018) 922
# ('RINTERNATIONALMIG', 2019) 922
# ('RINTERNATIONALMIG', 2020) 922
# ('RINTERNATIONALMIG', 2021) 922
# ('RINTERNATIONALMIG', 2022) 922
# ('RDOMESTICMIG', 2011) 922
# ('RDOMESTICMIG', 2012) 922
# ('RDOMESTICMIG', 2013) 922
# ('RDOMESTICMIG', 2014) 922
# ('RDOMESTICMIG', 2015) 922
# ('RDOMESTICMIG', 2016) 922
# ('RDOMESTICMIG', 2017) 922
# ('RDOMESTICMIG', 2018) 922
# ('RDOMESTICMIG', 2019) 922
# ('RDOMESTICMIG', 2020) 922
# ('RDOMESTICMIG', 2021) 922
# ('RDOMESTICMIG', 2022) 922
# ('RNETMIG', 2011) 922
# ('RNETMIG', 2012) 922
# ('RNETMIG', 2013) 922
# ('RNETMIG', 2014) 922
# ('RNETMIG', 2015) 922
# ('RNETMIG', 2016) 922
# ('RNETMIG', 2017) 922
# ('RNETMIG', 2018) 922
# ('RNETMIG', 2019) 922
# ('RNETMIG', 2020) 922
# ('RNETMIG', 2021) 922
# ('RNETMIG', 2022) 922
# ('avg_d_kbps', 2019) 926
# ('avg_d_kbps', 2020) 926
# ('avg_d_kbps', 2021) 926
# ('avg_u_kbps', 2019) 926
# ('avg_u_kbps', 2020) 926
# ('avg_u_kbps', 2021) 926
# ('avg_lat_ms', 2019) 926
# ('avg_lat_ms', 2020) 926
# ('avg_lat_ms', 2021) 926
# ('tests', 2019) 926
# ('tests', 2020) 926
# ('tests', 2021) 926
# ('devices', 2019) 926
# ('devices', 2020) 926
# ('devices', 2021) 926
# ('Annual Change (%)', 2010) 921
# ('Annual Change (%)', 2015) 921
# ('Annual Change (%)', 2019) 921
# ('Annual Change (%)', 2021) 922
# ('HPI', 2010) 921
# ('HPI', 2015) 921
# ('HPI', 2019) 921
# ('HPI', 2021) 922
# ('HPI with 1990 base', 2010) 781
# ('HPI with 1990 base', 2015) 781
# ('HPI with 1990 base', 2019) 781
# ('HPI with 1990 base', 2021) 781
# ('HPI with 2000 base', 2010) 918
# ('HPI with 2000 base', 2015) 918
# ('HPI with 2000 base', 2019) 918
# ('HPI with 2000 base', 2021) 918
# ('Total_Population', 2010) 926
# ('Total_Population', 2015) 926
# ('Total_Population', 2019) 926
# ('Total_Population', 2021) 926
# ('Total_Male_Pop', 2010) 926
# ('Total_Male_Pop', 2015) 926
# ('Total_Male_Pop', 2019) 926
# ('Total_Male_Pop', 2021) 926
# ('Total_Female_Pop', 2010) 926
# ('Total_Female_Pop', 2015) 926
# ('Total_Female_Pop', 2019) 926
# ('Total_Female_Pop', 2021) 926
# ('Median_Age', 2010) 926
# ('Median_Age', 2015) 926
# ('Median_Age', 2019) 926
# ('Median_Age', 2021) 926
# ('M_Median_Age', 2010) 926
# ('M_Median_Age', 2015) 926
# ('M_Median_Age', 2019) 926
# ('M_Median_Age', 2021) 926
# ('F_Median_Age', 2010) 926
# ('F_Median_Age', 2015) 926
# ('F_Median_Age', 2019) 926
# ('F_Median_Age', 2021) 926
# ('Race_white', 2010) 926
# ('Race_white', 2015) 926
# ('Race_white', 2019) 926
# ('Race_white', 2021) 926
# ('Race_black', 2010) 926
# ('Race_black', 2015) 926
# ('Race_black', 2019) 926
# ('Race_black', 2021) 926
# ('Race_Am_Indian', 2010) 926
# ('Race_Am_Indian', 2015) 926
# ('Race_Am_Indian', 2019) 926
# ('Race_Am_Indian', 2021) 926
# ('Race_Asian', 2010) 926
# ('Race_Asian', 2015) 926
# ('Race_Asian', 2019) 926
# ('Race_Asian', 2021) 926
# ('Race_Pac_Isl', 2010) 926
# ('Race_Pac_Isl', 2015) 926
# ('Race_Pac_Isl', 2019) 926
# ('Race_Pac_Isl', 2021) 926
# ('Median_Income', 2010) 925
# ('Median_Income', 2015) 894
# ('Median_Income', 2019) 926
# ('Median_Income', 2021) 926
# ('Less_High', 2010) 925
# ('Less_High', 2015) 893
# ('Less_High', 2019) 925
# ('Less_High', 2021) 922
# ('High_Equiv', 2010) 925
# ('High_Equiv', 2015) 894
# ('High_Equiv', 2019) 926
# ('High_Equiv', 2021) 926
# ('College_Assoc_Equiv', 2010) 925
# ('College_Assoc_Equiv', 2015) 894
# ('College_Assoc_Equiv', 2019) 926
# ('College_Assoc_Equiv', 2021) 926
# ('Bachelors', 2010) 925
# ('Bachelors', 2015) 893
# ('Bachelors', 2019) 926
# ('Bachelors', 2021) 925
# ('Grad_Prof', 2010) 925
# ('Grad_Prof', 2015) 893
# ('Grad_Prof', 2019) 925
# ('Grad_Prof', 2021) 924
# ('Ag_For_Fish_Hunt_Mine', 2010) 926
# ('Ag_For_Fish_Hunt_Mine', 2015) 926
# ('Ag_For_Fish_Hunt_Mine', 2019) 926
# ('Ag_For_Fish_Hunt_Mine', 2021) 926
# ('Construction', 2010) 926
# ('Construction', 2015) 926
# ('Construction', 2019) 926
# ('Construction', 2021) 926
# ('Manufacturing', 2010) 926
# ('Manufacturing', 2015) 926
# ('Manufacturing', 2019) 926
# ('Manufacturing', 2021) 926
# ('Wholesale', 2010) 925
# ('Wholesale', 2015) 924
# ('Wholesale', 2019) 924
# ('Wholesale', 2021) 923
# ('Retail', 2010) 926
# ('Retail', 2015) 926
# ('Retail', 2019) 926
# ('Retail', 2021) 926
# ('Trans_Ware_Util', 2010) 926
# ('Trans_Ware_Util', 2015) 926
# ('Trans_Ware_Util', 2019) 926
# ('Trans_Ware_Util', 2021) 926
# ('Information', 2010) 922
# ('Information', 2015) 922
# ('Information', 2019) 916
# ('Information', 2021) 914
# ('Fin_Insur_Real', 2010) 926
# ('Fin_Insur_Real', 2015) 926
# ('Fin_Insur_Real', 2019) 926
# ('Fin_Insur_Real', 2021) 926
# ('Fin_Insur', 2010) 926
# ('Fin_Insur', 2015) 925
# ('Fin_Insur', 2019) 924
# ('Fin_Insur', 2021) 926
# ('Real_Rental', 2010) 925
# ('Real_Rental', 2015) 920
# ('Real_Rental', 2019) 923
# ('Real_Rental', 2021) 919
# ('Prof_Sci_Tech', 2010) 925
# ('Prof_Sci_Tech', 2015) 925
# ('Prof_Sci_Tech', 2019) 926
# ('Prof_Sci_Tech', 2021) 924
# ('Mngmt_Enter', 2010) 422
# ('Mngmt_Enter', 2015) 296
# ('Mngmt_Enter', 2019) 371
# ('Mngmt_Enter', 2021) 384
# ('Admin_WstMngmt', 2010) 926
# ('Admin_WstMngmt', 2015) 925
# ('Admin_WstMngmt', 2019) 926
# ('Admin_WstMngmt', 2021) 926
# ('Ed_Servc', 2010) 926
# ('Ed_Servc', 2015) 926
# ('Ed_Servc', 2019) 926
# ('Ed_Servc', 2021) 926
# ('Hlthcr_Social', 2010) 926
# ('Hlthcr_Social', 2015) 926
# ('Hlthcr_Social', 2019) 926
# ('Hlthcr_Social', 2021) 926
# ('Arts_Entr_Rec', 2010) 920
# ('Arts_Entr_Rec', 2015) 916
# ('Arts_Entr_Rec', 2019) 917
# ('Arts_Entr_Rec', 2021) 918
# ('Accom_Food_Srvc', 2010) 926
# ('Accom_Food_Srvc', 2015) 926
# ('Accom_Food_Srvc', 2019) 926
# ('Accom_Food_Srvc', 2021) 926
# ('Other_Servc', 2010) 926
# ('Other_Servc', 2015) 926
# ('Other_Servc', 2019) 926
# ('Other_Servc', 2021) 926
# ('Public_admin', 2010) 926
# ('Public_admin', 2015) 926
# ('Public_admin', 2019) 926
# ('Public_admin', 2021) 926
# ('Sal_Avg_Occ', 2010) 926
# ('Sal_Avg_Occ', 2015) 926
# ('Sal_Avg_Occ', 2019) 926
# ('Sal_Avg_Occ', 2021) 926
# ('Avg_Comp_EngSci', 2010) 924
# ('Avg_Comp_EngSci', 2015) 924
# ('Avg_Comp_EngSci', 2019) 924
# ('Avg_Comp_EngSci', 2021) 924
# ('Avg_Mngmt_Bus_Fin', 2010) 926
# ('Avg_Mngmt_Bus_Fin', 2015) 926
# ('Avg_Mngmt_Bus_Fin', 2019) 926
# ('Avg_Mngmt_Bus_Fin', 2021) 926
# ('Num_Workers', 2010) 926
# ('Num_Workers', 2015) 926
# ('Num_Workers', 2019) 926
# ('Num_Workers', 2021) 926
# ('Num_Worked_Home', 2010) 926
# ('Num_Worked_Home', 2015) 926
# ('Num_Worked_Home', 2019) 926
# ('Num_Worked_Home', 2021) 926
# ('Worked_Home_White', 2010) 926
# ('Worked_Home_White', 2015) 926
# ('Worked_Home_White', 2019) 926
# ('Worked_Home_White', 2021) 926
# ('Worked_Home_Black', 2010) 926
# ('Worked_Home_Black', 2015) 926
# ('Worked_Home_Black', 2019) 926
# ('Worked_Home_Black', 2021) 926
# ('Worked_Home_NA', 2010) 926
# ('Worked_Home_NA', 2015) 926
# ('Worked_Home_NA', 2019) 926
# ('Worked_Home_NA', 2021) 926
# ('Worked_Home_Asian', 2010) 926
# ('Worked_Home_Asian', 2015) 926
# ('Worked_Home_Asian', 2019) 926
# ('Worked_Home_Asian', 2021) 926
# ('Worked_Home_White_Not_Hispanic', 2010) 926
# ('Worked_Home_White_Not_Hispanic', 2015) 926
# ('Worked_Home_White_Not_Hispanic', 2019) 926
# ('Worked_Home_White_Not_Hispanic', 2021) 926
# ('Worked_Home_White_Hispanic', 2010) 926
# ('Worked_Home_White_Hispanic', 2015) 926
# ('Worked_Home_White_Hispanic', 2019) 926
# ('Worked_Home_White_Hispanic', 2021) 926
# ('Education_Pop', 2010) 926
# ('Education_Pop', 2015) 926
# ('Education_Pop', 2019) 926
# ('Education_Pop', 2021) 926
# ('Pop_Less_HS', 2010) 926
# ('Pop_Less_HS', 2015) 926
# ('Pop_Less_HS', 2019) 926
# ('Pop_Less_HS', 2021) 926
# ('Pop_HS_Grad', 2010) 926
# ('Pop_HS_Grad', 2015) 926
# ('Pop_HS_Grad', 2019) 926
# ('Pop_HS_Grad', 2021) 926
# ('Pop_Some_College', 2010) 926
# ('Pop_Some_College', 2015) 926
# ('Pop_Some_College', 2019) 926
# ('Pop_Some_College', 2021) 926
# ('Pop_Bachelors', 2010) 926
# ('Pop_Bachelors', 2015) 926
# ('Pop_Bachelors', 2019) 926
# ('Pop_Bachelors', 2021) 926
# ('Pop_Grad', 2010) 926
# ('Pop_Grad', 2015) 926
# ('Pop_Grad', 2019) 926
# ('Pop_Grad', 2021) 926
# ('Pop_Worked_Home', 2010) 926
# ('Pop_Worked_Home', 2015) 926
# ('Pop_Worked_Home', 2019) 926
# ('Pop_Worked_Home', 2021) 926
# ('Pop_Worked_Home_1-10k', 2010) 926
# ('Pop_Worked_Home_1-10k', 2015) 926
# ('Pop_Worked_Home_1-10k', 2019) 926
# ('Pop_Worked_Home_1-10k', 2021) 926
# ('Pop_Worked_Home_10k-15k', 2010) 926
# ('Pop_Worked_Home_10k-15k', 2015) 926
# ('Pop_Worked_Home_10k-15k', 2019) 926
# ('Pop_Worked_Home_10k-15k', 2021) 926
# ('Pop_Worked_Home_15k-25k', 2010) 926
# ('Pop_Worked_Home_15k-25k', 2015) 926
# ('Pop_Worked_Home_15k-25k', 2019) 926
# ('Pop_Worked_Home_15k-25k', 2021) 926
# ('Pop_Worked_Home_25k-35k', 2010) 926
# ('Pop_Worked_Home_25k-35k', 2015) 926
# ('Pop_Worked_Home_25k-35k', 2019) 926
# ('Pop_Worked_Home_25k-35k', 2021) 926
# ('Pop_Worked_Home_35k-50k', 2010) 926
# ('Pop_Worked_Home_35k-50k', 2015) 926
# ('Pop_Worked_Home_35k-50k', 2019) 926
# ('Pop_Worked_Home_35k-50k', 2021) 926
# ('Pop_Worked_Home_50k-65k', 2010) 926
# ('Pop_Worked_Home_50k-65k', 2015) 926
# ('Pop_Worked_Home_50k-65k', 2019) 926
# ('Pop_Worked_Home_50k-65k', 2021) 926
# ('Pop_Worked_Home_65k-75k', 2010) 926
# ('Pop_Worked_Home_65k-75k', 2015) 926
# ('Pop_Worked_Home_65k-75k', 2019) 926
# ('Pop_Worked_Home_65k-75k', 2021) 926
# ('Pop_Worked_Home_75k-more', 2010) 926
# ('Pop_Worked_Home_75k-more', 2015) 926
# ('Pop_Worked_Home_75k-more', 2019) 926
# ('Pop_Worked_Home_75k-more', 2021) 926
# ('Median_Income_Worked_home', 2010) 926
# ('Median_Income_Worked_home', 2015) 640
# ('Median_Income_Worked_home', 2019) 895
# ('Median_Income_Worked_home', 2021) 895
# ('Pop_HS_Above', 2010) 926
# ('Pop_HS_Above', 2015) 926
# ('Pop_HS_Above', 2019) 926
# ('Pop_HS_Above', 2021) 926
# ('Pop_BS_Above', 2010) 926
# ('Pop_BS_Above', 2015) 926
# ('Pop_BS_Above', 2019) 926
# ('Pop_BS_Above', 2021) 926
# ('Pct_Less_HS', 2010) 926
# ('Pct_Less_HS', 2015) 926
# ('Pct_Less_HS', 2019) 926
# ('Pct_Less_HS', 2021) 926
# ('Pct_HS_Grad', 2010) 926
# ('Pct_HS_Grad', 2015) 926
# ('Pct_HS_Grad', 2019) 926
# ('Pct_HS_Grad', 2021) 926
# ('Pct_Some_College', 2010) 926
# ('Pct_Some_College', 2015) 926
# ('Pct_Some_College', 2019) 926
# ('Pct_Some_College', 2021) 926
# ('Pct_Bachelors', 2010) 926
# ('Pct_Bachelors', 2015) 926
# ('Pct_Bachelors', 2019) 926
# ('Pct_Bachelors', 2021) 926
# ('Pct_Grad', 2010) 926
# ('Pct_Grad', 2015) 926
# ('Pct_Grad', 2019) 926
# ('Pct_Grad', 2021) 926
# ('Pct_HS_Above', 2010) 926
# ('Pct_HS_Above', 2015) 926
# ('Pct_HS_Above', 2019) 926
# ('Pct_HS_Above', 2021) 926
# ('Pct_BS_Above', 2010) 926
# ('Pct_BS_Above', 2015) 926
# ('Pct_BS_Above', 2019) 926
# ('Pct_BS_Above', 2021) 926
# ('Tot_Bldgs', 2010) 919
# ('Tot_Bldgs', 2015) 922
# ('Tot_Bldgs', 2019) 922
# ('Tot_Bldgs', 2021) 922
# ('Tot_Bldgs_Value', 2010) 919
# ('Tot_Bldgs_Value', 2015) 922
# ('Tot_Bldgs_Value', 2019) 922
# ('Tot_Bldgs_Value', 2021) 922
# ('Tot_Units', 2010) 919
# ('Tot_Units', 2015) 922
# ('Tot_Units', 2019) 922
# ('Tot_Units', 2021) 922
