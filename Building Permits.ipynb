# %%
import pandas as pd
import geopandas as gp 
import matplotlib as plt

# %%
permits2022 = pd.read_excel('msaannual_202299.xls', skiprows = 5)
permits2010 = pd.read_csv('tb3u2010.txt', delim_whitespace=True, skiprows = 9)

# %%
permits2010 = permits2010.rename(columns = {'Total': 'State', '1': 'Total2010', 'Unit': '1 Unit', '2': '2 Units', 'Units' : '3 and 4 Units', 'Units.1' : '5 Units or more','or' : 'Number of structures with 5 Units or more' })

# %%
sharedFolder = "/work/group/egodat/reu23_clark/"
gdf = pd.read_pickle(sharedFolder + "gdf.pkl")

# %%
gdf.columns
# Out:
# Index(['CBSA', 'LSAD', 'POPESTIMATE2020', 'POPESTIMATE2021', 'POPESTIMATE2022',
#        'NAME', 'geometry', 'metro', 'micro', 'buff', 'inBuff',
#        'commuteBuffCount_19', 'workingPop_19', 'commutePercent_19',
#        'commuteBuffCount_20', 'workingPop_20', 'commutePercent_20', 'liminal'],
#       dtype='object')

# %%
merged = pd.merge(permits2022, gdf, on = 'CBSA')

# %%
gdf
# Out:
#       CBSA                           LSAD  POPESTIMATE2020  POPESTIMATE2021  \
# 0    10180  Metropolitan Statistical Area           176866           177829
# 1    10420  Metropolitan Statistical Area           701625           696225
# 2    10500  Metropolitan Statistical Area           148244           144922
# 3    10540  Metropolitan Statistical Area           128978           129948
# 4    10580  Metropolitan Statistical Area           899748           905369
# ..     ...                            ...              ...              ...
# 921  49300  Micropolitan Statistical Area           116906           116129
# 922  49380  Micropolitan Statistical Area            22207            22047
# 923  49460  Micropolitan Statistical Area            23282            23334
# 924  49780  Micropolitan Statistical Area            86450            86574
# 925  49820  Micropolitan Statistical Area            13874            13893
#
#      POPESTIMATE2022                         NAME  \
# ...

# %%
small = permits2010[['CBSA','Total2010']]

# %%
small = small[:-2]

# %%
small['CBSA'] = small['CBSA'].astype(int)
# Out:
# /tmp/ipykernel_426123/3450794548.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   small['CBSA'] = small['CBSA'].astype(int)

# %%
merged2 = pd.merge(merged, small, on = 'CBSA')

# %%
onlyLim = merged2[merged2['liminal'] == True]

# %%
# Out:
# 50     MO-IL
# 73       131
# 76        93
# 78       161
# 81        13
# 99        76
# 168       18
# 232       NJ
# 274       55
# 328      103
# Name: Total2010, dtype: object

# %%
onlyLimDes = gdf[gdf['liminal'] == True]

# %%
LimAndMetro = onlyLimDes[onlyLimDes['LSAD'] == 'Metropolitan Statistical Area']

# %%
LimAndMetro
# Out:
#       CBSA                           LSAD  POPESTIMATE2020  POPESTIMATE2021  \
# 40   14100  Metropolitan Statistical Area            82811            83083
# 55   16020  Metropolitan Statistical Area            97543            97757
# 80   18020  Metropolitan Statistical Area            82216            82730
# 83   18700  Metropolitan Statistical Area            95208            96277
# 85   19060  Metropolitan Statistical Area            94845            94557
# 88   19180  Metropolitan Statistical Area            74001            73263
# 108  21300  Metropolitan Statistical Area            83945            82830
# 110  21420  Metropolitan Statistical Area            62692            61947
# 186  29020  Metropolitan Statistical Area            83588            83642
# 227  33220  Metropolitan Statistical Area            83481            83426
# 254  36140  Metropolitan Statistical Area            95040            95768
# ...
